# %%
import pandas as pd

link = 'C:/Users/Kanel/vEnv/trabalho-final/database/Financial-Data.csv'

df = pd.read_csv(link)
df
# Out:
#        Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# 0                   3                     3                   6
# 1                   6                     3                   2
# 2                   0                     0                   7
# 3                   6                     1                   2
# 4                   5                     2                   2
# ...               ...                   ...                 ...
# 17903               5                     3                   2
# 17904               2                     1                   3
# 17905               5                     1                   1
# 17906               3                     5                   6
# 17907               4                    10                   4
#
#        personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                       2  ...               550       36200      0.737398
# 1                       7  ...               600       30150      0.738510
# 2                       1  ...               450       34550      0.642993
# 3                       7  ...               700       42150      0.665224
# 4                       8  ...              1100       53850      0.617361
# ...                   ...  ...               ...         ...           ...
# 17903                   6  ...               700       71700      0.691126
# 17904                   3  ...               800       51800      0.648525
# 17905                   8  ...              1200       59650      0.677975
# 17906                   1  ...               400       80200      0.642741
# 17907                   1  ...               600       64950      0.720889
#
#        risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0          0.903517      0.487712      0.515977           0.580918
# 1          0.881027      0.713423      0.826402           0.730720
# 2          0.766554      0.595018      0.762284           0.531712
# 3          0.960832      0.767828      0.778831           0.792552
# 4          0.857560      0.613487      0.665523           0.744634
# ...             ...           ...           ...                ...
# 17903      0.928196      0.664112      0.838012           0.727705
# 17904      0.970832      0.699241      0.844724           0.774918
# 17905      0.918141      0.687981      0.939101           0.472045
# 17906      0.885684      0.456448      0.686823           0.406568
# 17907      0.874372      0.505565      0.631619           0.846163
#
#        ext_quality_score_2  inquiries_last_month  e_signed
# 0                 0.380918                    10         1
# 1                 0.630720                     9         0
# 2                 0.531712                     7         0
# 3                 0.592552                     8         1
# 4                 0.744634                    12         0
# ...                    ...                   ...       ...
# 17903             0.627705                     2         0
# 17904             0.474918                     3         0
# 17905             0.672045                     9         0
# 17906             0.406568                     3         1
# 17907             0.846163                     4         1
#
# [17908 rows x 21 columns]

# %%
y = df['e_signed'] # coluna-alvo
x = df[[
    'risk_score', 'amount_requested', 'has_debt', 'income' 
]]

# %%
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size=0.3, random_state=2811)

print(f"Train Set: {x_train.shape}, \nTest Set: {x_test.shape}")
# Out:
# Train Set: (12535, 4),
# Test Set: (5373, 4)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predicts = model.predict(x_test)

# %%
from sklearn import metrics

# %%
print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
# Out:
# Accuracy: 0.601
# F1-Score: 0.637
# Recall: 0.6543
# Precision: 0.6206
# EQM: 0.399

# %% [markdown]
# #### Realizando modificações

# %%
RandomForestClassifier?

# %%
nEst = [10, 50, 100, 150, 200]
crit = ['gini', 'entropy', 'log_loss']
maxFeat = ['sqrt', 'log2']

# %%
for x in range(len(crit)):
    for y in range(len(maxFeat)):
        for z in range(len(nEst)):
            print(f'Usando criterion={crit[x]}, max_features={maxFeat[y]} e n_estimators={nEst[z]}:')
            model = RandomForestClassifier(criterion=crit[x], max_features=maxFeat[y], n_estimators=nEst[z])
            model.fit(x_train, y_train)
            print(f'Score treino: {model.score(x_train, y_train).round(4)}')
            predicts = model.predict(x_test)
            print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
            print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
            print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
            print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
            print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
            print('')
# Out:
# Usando criterion=gini, max_features=sqrt e n_estimators=10:
# Score treino: 0.9801
# Accuracy: 0.5844
# F1-Score: 0.5966
# Recall: 0.5743
# Precision: 0.6207
# EQM: 0.4156
#
# Usando criterion=gini, max_features=sqrt e n_estimators=50:
# Score treino: 0.9991
# Accuracy: 0.5941
# F1-Score: 0.627
# Recall: 0.6376
# Precision: 0.6168
# EQM: 0.4059
#
# Usando criterion=gini, max_features=sqrt e n_estimators=100:
# Score treino: 0.9998
# Accuracy: 0.5997
# F1-Score: 0.6337
# Recall: 0.6473
# Precision: 0.6207
# EQM: 0.4003
#
# Usando criterion=gini, max_features=sqrt e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.6017
# F1-Score: 0.6381
# Recall: 0.6563
# Precision: 0.6209
# EQM: 0.3983
#
# Usando criterion=gini, max_features=sqrt e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.606
# F1-Score: 0.6409
# Recall: 0.657
# Precision: 0.6255
# EQM: 0.394
#
# Usando criterion=gini, max_features=log2 e n_estimators=10:
# Score treino: 0.9801
# Accuracy: 0.5831
# F1-Score: 0.5983
# Recall: 0.5802
# Precision: 0.6175
# EQM: 0.4169
#
# Usando criterion=gini, max_features=log2 e n_estimators=50:
# Score treino: 0.9996
# Accuracy: 0.6054
# F1-Score: 0.6354
# Recall: 0.6424
# Precision: 0.6284
# EQM: 0.3946
#
# Usando criterion=gini, max_features=log2 e n_estimators=100:
# Score treino: 0.9998
# Accuracy: 0.5956
# F1-Score: 0.6303
# Recall: 0.6442
# Precision: 0.6169
# EQM: 0.4044
#
# Usando criterion=gini, max_features=log2 e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.6002
# F1-Score: 0.6368
# Recall: 0.655
# Precision: 0.6196
# EQM: 0.3998
#
# Usando criterion=gini, max_features=log2 e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.6054
# F1-Score: 0.6404
# Recall: 0.6567
# Precision: 0.625
# EQM: 0.3946
#
# Usando criterion=entropy, max_features=sqrt e n_estimators=10:
# Score treino: 0.9788
# Accuracy: 0.5876
# F1-Score: 0.5964
# Recall: 0.5694
# Precision: 0.626
# EQM: 0.4124
#
# Usando criterion=entropy, max_features=sqrt e n_estimators=50:
# Score treino: 0.9995
# Accuracy: 0.5956
# F1-Score: 0.6284
# Recall: 0.639
# Precision: 0.6181
# EQM: 0.4044
#
# Usando criterion=entropy, max_features=sqrt e n_estimators=100:
# Score treino: 0.9997
# Accuracy: 0.5982
# F1-Score: 0.6321
# Recall: 0.6452
# Precision: 0.6196
# EQM: 0.4018
#
# Usando criterion=entropy, max_features=sqrt e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.6015
# F1-Score: 0.6371
# Recall: 0.6536
# Precision: 0.6214
# EQM: 0.3985
#
# Usando criterion=entropy, max_features=sqrt e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.6023
# F1-Score: 0.6363
# Recall: 0.6501
# Precision: 0.623
# EQM: 0.3977
#
# Usando criterion=entropy, max_features=log2 e n_estimators=10:
# Score treino: 0.9773
# Accuracy: 0.5838
# F1-Score: 0.5943
# Recall: 0.5697
# Precision: 0.6212
# EQM: 0.4162
#
# Usando criterion=entropy, max_features=log2 e n_estimators=50:
# Score treino: 0.9995
# Accuracy: 0.5913
# F1-Score: 0.6235
# Recall: 0.6323
# Precision: 0.6148
# EQM: 0.4087
#
# Usando criterion=entropy, max_features=log2 e n_estimators=100:
# Score treino: 0.9998
# Accuracy: 0.6039
# F1-Score: 0.6369
# Recall: 0.649
# Precision: 0.6251
# EQM: 0.3961
#
# Usando criterion=entropy, max_features=log2 e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.6021
# F1-Score: 0.6375
# Recall: 0.6539
# Precision: 0.6219
# EQM: 0.3979
#
# Usando criterion=entropy, max_features=log2 e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.6012
# F1-Score: 0.6365
# Recall: 0.6525
# Precision: 0.6212
# EQM: 0.3988
#
# Usando criterion=log_loss, max_features=sqrt e n_estimators=10:
# Score treino: 0.9781
# Accuracy: 0.59
# F1-Score: 0.6005
# Recall: 0.576
# Precision: 0.6273
# EQM: 0.41
#
# Usando criterion=log_loss, max_features=sqrt e n_estimators=50:
# Score treino: 0.9992
# Accuracy: 0.6004
# F1-Score: 0.6324
# Recall: 0.6424
# Precision: 0.6227
# EQM: 0.3996
#
# Usando criterion=log_loss, max_features=sqrt e n_estimators=100:
# Score treino: 0.9998
# Accuracy: 0.603
# F1-Score: 0.6373
# Recall: 0.6518
# Precision: 0.6234
# EQM: 0.397
#
# Usando criterion=log_loss, max_features=sqrt e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.601
# F1-Score: 0.6371
# Recall: 0.6546
# Precision: 0.6205
# EQM: 0.399
#
# Usando criterion=log_loss, max_features=sqrt e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.6062
# F1-Score: 0.6407
# Recall: 0.6563
# Precision: 0.6259
# EQM: 0.3938
#
# Usando criterion=log_loss, max_features=log2 e n_estimators=10:
# Score treino: 0.9791
# Accuracy: 0.5965
# F1-Score: 0.6098
# Recall: 0.5892
# Precision: 0.6319
# EQM: 0.4035
#
# Usando criterion=log_loss, max_features=log2 e n_estimators=50:
# Score treino: 0.9994
# Accuracy: 0.5965
# F1-Score: 0.6281
# Recall: 0.6369
# Precision: 0.6196
# EQM: 0.4035
#
# Usando criterion=log_loss, max_features=log2 e n_estimators=100:
# Score treino: 0.9998
# Accuracy: 0.5987
# F1-Score: 0.6321
# Recall: 0.6442
# Precision: 0.6204
# EQM: 0.4013
#
# Usando criterion=log_loss, max_features=log2 e n_estimators=150:
# Score treino: 0.9998
# Accuracy: 0.5989
# F1-Score: 0.6337
# Recall: 0.6483
# Precision: 0.6197
# EQM: 0.4011
#
# Usando criterion=log_loss, max_features=log2 e n_estimators=200:
# Score treino: 0.9998
# Accuracy: 0.6038
# F1-Score: 0.6391
# Recall: 0.6557
# Precision: 0.6233
# EQM: 0.3962
