# %% [markdown]
# ## Modificando o algoritmo SVM

# %%
import pandas as pd

link = 'C:/Users/Kanel/vEnv/trabalho-final/database/Financial-Data.csv'

df = pd.read_csv(link)
df
# Out:
#        Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# 0                   3                     3                   6
# 1                   6                     3                   2
# 2                   0                     0                   7
# 3                   6                     1                   2
# 4                   5                     2                   2
# ...               ...                   ...                 ...
# 17903               5                     3                   2
# 17904               2                     1                   3
# 17905               5                     1                   1
# 17906               3                     5                   6
# 17907               4                    10                   4
#
#        personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                       2  ...               550       36200      0.737398
# 1                       7  ...               600       30150      0.738510
# 2                       1  ...               450       34550      0.642993
# 3                       7  ...               700       42150      0.665224
# 4                       8  ...              1100       53850      0.617361
# ...                   ...  ...               ...         ...           ...
# 17903                   6  ...               700       71700      0.691126
# 17904                   3  ...               800       51800      0.648525
# 17905                   8  ...              1200       59650      0.677975
# 17906                   1  ...               400       80200      0.642741
# 17907                   1  ...               600       64950      0.720889
#
#        risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0          0.903517      0.487712      0.515977           0.580918
# 1          0.881027      0.713423      0.826402           0.730720
# 2          0.766554      0.595018      0.762284           0.531712
# 3          0.960832      0.767828      0.778831           0.792552
# 4          0.857560      0.613487      0.665523           0.744634
# ...             ...           ...           ...                ...
# 17903      0.928196      0.664112      0.838012           0.727705
# 17904      0.970832      0.699241      0.844724           0.774918
# 17905      0.918141      0.687981      0.939101           0.472045
# 17906      0.885684      0.456448      0.686823           0.406568
# 17907      0.874372      0.505565      0.631619           0.846163
#
#        ext_quality_score_2  inquiries_last_month  e_signed
# 0                 0.380918                    10         1
# 1                 0.630720                     9         0
# 2                 0.531712                     7         0
# 3                 0.592552                     8         1
# 4                 0.744634                    12         0
# ...                    ...                   ...       ...
# 17903             0.627705                     2         0
# 17904             0.474918                     3         0
# 17905             0.672045                     9         0
# 17906             0.406568                     3         1
# 17907             0.846163                     4         1
#
# [17908 rows x 21 columns]

# %%
y = df['e_signed'] # coluna-alvo
x = df[[
    'risk_score', 'amount_requested', 'has_debt', 'income' 
]] # colunas com melhor correlação de Pearson

# x = df -> para usar todas as features

# %%
# dataset em 30% para testes
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size=0.3, random_state=2811)

print(f"Train Set: {x_train.shape}, \nTest Set: {x_test.shape}")
# Out:
# Train Set: (12535, 4),
# Test Set: (5373, 4)

# %%
from sklearn.svm import SVC

model = SVC()

# %%
# -> ajustando o conj. treino
model.fit(x_train, y_train)

# -> mostrar acuracia do treino
predicts = model.predict(x_test)

# %%
# resultados do R2 Score
from sklearn import metrics

print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
# Out:
# Accuracy: 0.5503
# F1-Score: 0.6842
# Recall: 0.9103
# Precision: 0.5481
# EQM: 0.4497

# %% [markdown]
# Realizando modificações

# %%
C = [0.1, 1, 10, 100]
krn = ['linear', 'poly', 'rbf', 'sigmoid']

# %%
for x in range(len(C)):
    for y in range(len(krn)):
            print(f'Usando C={C[x]} e kernel={krn[y]}:')
            model = SVC(C=C[x], kernel=krn[y])
            model.fit(x_train, y_train)
            print(f'Score treino: {model.score(x_train, y_train).round(4)}')
            predicts = model.predict(x_test)
            print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
            print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
            print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
            print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
            print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
            print('')
# Out:
# Usando C=0.1 e kernel=linear:
# Score treino: 0.5292
# Accuracy: 0.5312
# F1-Score: 0.6638
# Recall: 0.865
# Precision: 0.5385
# EQM: 0.4688
#
# Usando C=0.1 e kernel=poly:
# Score treino: 0.5396
# Accuracy: 0.5351
# F1-Score: 0.6971
# Recall: 1.0
# Precision: 0.5351
# EQM: 0.4649
#
# Usando C=0.1 e kernel=rbf:
# Score treino: 0.5448
# Accuracy: 0.5399
# F1-Score: 0.6899
# Recall: 0.9565
# Precision: 0.5395
# EQM: 0.4601
#
# Usando C=0.1 e kernel=sigmoid:
# Score treino: 0.475
# Accuracy: 0.4532
# F1-Score: 0.4882
# Recall: 0.4873
# Precision: 0.489
# EQM: 0.5468
#
# Usando C=1 e kernel=linear:
# Score treino: 0.5312
# Accuracy: 0.5345
# F1-Score: 0.6717
# Recall: 0.8897
# Precision: 0.5394
# EQM: 0.4655
#
# Usando C=1 e kernel=poly:
# Score treino: 0.5396
# Accuracy: 0.5351
# F1-Score: 0.6971
# Recall: 1.0
# Precision: 0.5351
# EQM: 0.4649
#
# Usando C=1 e kernel=rbf:
# Score treino: 0.5526
# Accuracy: 0.5503
# F1-Score: 0.6842
# Recall: 0.9103
# Precision: 0.5481
# EQM: 0.4497
#
# Usando C=1 e kernel=sigmoid:
# Score treino: 0.4744
# Accuracy: 0.453
# F1-Score: 0.4856
# Recall: 0.4824
# Precision: 0.4887
# EQM: 0.547
#
# Usando C=10 e kernel=linear:
# Score treino: 0.5303
# Accuracy: 0.5351
# F1-Score: 0.6578
# Recall: 0.8351
# Precision: 0.5426
# EQM: 0.4649
#
# Usando C=10 e kernel=poly:
# Score treino: 0.5396
# Accuracy: 0.5351
# F1-Score: 0.6971
# Recall: 1.0
# Precision: 0.5351
# EQM: 0.4649
#
# Usando C=10 e kernel=rbf:
# Score treino: 0.5548
# Accuracy: 0.5524
# F1-Score: 0.6843
# Recall: 0.9068
# Precision: 0.5495
# EQM: 0.4476
#
# Usando C=10 e kernel=sigmoid:
# Score treino: 0.4745
# Accuracy: 0.4534
# F1-Score: 0.4854
# Recall: 0.4817
# Precision: 0.4891
# EQM: 0.5466
#
# Usando C=100 e kernel=linear:
# Score treino: 0.5323
# Accuracy: 0.533
# F1-Score: 0.6698
# Recall: 0.8852
# Precision: 0.5387
# EQM: 0.467
#
# Usando C=100 e kernel=poly:
# Score treino: 0.5402
# Accuracy: 0.5362
# F1-Score: 0.6976
# Recall: 1.0
# Precision: 0.5357
# EQM: 0.4638
#
# Usando C=100 e kernel=rbf:
# Score treino: 0.5566
# Accuracy: 0.5583
# F1-Score: 0.6898
# Recall: 0.9176
# Precision: 0.5526
# EQM: 0.4417
#
# Usando C=100 e kernel=sigmoid:
# Score treino: 0.4746
# Accuracy: 0.4534
# F1-Score: 0.4854
# Recall: 0.4817
# Precision: 0.4891
# EQM: 0.5466
