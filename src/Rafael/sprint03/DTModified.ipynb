# %%
import pandas as pd

link = 'C:/Users/Kanel/vEnv/trabalho-final/database/Financial-Data.csv'

df = pd.read_csv(link)
df
# Out:
#        Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# 0                   3                     3                   6
# 1                   6                     3                   2
# 2                   0                     0                   7
# 3                   6                     1                   2
# 4                   5                     2                   2
# ...               ...                   ...                 ...
# 17903               5                     3                   2
# 17904               2                     1                   3
# 17905               5                     1                   1
# 17906               3                     5                   6
# 17907               4                    10                   4
#
#        personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                       2  ...               550       36200      0.737398
# 1                       7  ...               600       30150      0.738510
# 2                       1  ...               450       34550      0.642993
# 3                       7  ...               700       42150      0.665224
# 4                       8  ...              1100       53850      0.617361
# ...                   ...  ...               ...         ...           ...
# 17903                   6  ...               700       71700      0.691126
# 17904                   3  ...               800       51800      0.648525
# 17905                   8  ...              1200       59650      0.677975
# 17906                   1  ...               400       80200      0.642741
# 17907                   1  ...               600       64950      0.720889
#
#        risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0          0.903517      0.487712      0.515977           0.580918
# 1          0.881027      0.713423      0.826402           0.730720
# 2          0.766554      0.595018      0.762284           0.531712
# 3          0.960832      0.767828      0.778831           0.792552
# 4          0.857560      0.613487      0.665523           0.744634
# ...             ...           ...           ...                ...
# 17903      0.928196      0.664112      0.838012           0.727705
# 17904      0.970832      0.699241      0.844724           0.774918
# 17905      0.918141      0.687981      0.939101           0.472045
# 17906      0.885684      0.456448      0.686823           0.406568
# 17907      0.874372      0.505565      0.631619           0.846163
#
#        ext_quality_score_2  inquiries_last_month  e_signed
# 0                 0.380918                    10         1
# 1                 0.630720                     9         0
# 2                 0.531712                     7         0
# 3                 0.592552                     8         1
# 4                 0.744634                    12         0
# ...                    ...                   ...       ...
# 17903             0.627705                     2         0
# 17904             0.474918                     3         0
# 17905             0.672045                     9         0
# 17906             0.406568                     3         1
# 17907             0.846163                     4         1
#
# [17908 rows x 21 columns]

# %%
y = df['e_signed'] # coluna-alvo
x = df[[
    'risk_score', 'amount_requested', 'has_debt', 'income' 
]] # colunas com melhor correlação de Pearson

# x = df -> para usar todas as features

# %%
# dataset em 30% para testes
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size=0.3, random_state=2811)

print(f"Train Set: {x_train.shape}, \nTest Set: {x_test.shape}")
# Out:
# Train Set: (12535, 4),
# Test Set: (5373, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)

model.score(x_train, y_train)
# Out:
# 0.9997606701236538

# %%
predicts = model.predict(x_test)

# %%
from sklearn import metrics

# %%
print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
# Out:
# Accuracy: 0.5636
# F1-Score: 0.59
# Recall: 0.5868
# Precision: 0.5932
# EQM: 0.4364

# %% [markdown]
# #### Realizando modificações

# %%
DecisionTreeClassifier?

# %%
crit = ['gini', 'entropy', 'log_loss']
maxFeat = ['auto', 'sqrt', 'log2']

# %%
for x in range(len(crit)):
    for y in range(len(maxFeat)):
        print(f'Usando criterion={crit[x]} e max_features={maxFeat[y]}:')
        model = DecisionTreeClassifier(criterion=crit[x], max_features=maxFeat[y])
        model.fit(x_train, y_train)
        print(f'Score treino: {model.score(x_train, y_train).round(4)}')
        predicts = model.predict(x_test)
        print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
        print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
        print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
        print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
        print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
        print('')
# Out:
# Usando criterion=gini e max_features=auto:
# Score treino: 0.9998
# Accuracy: 0.5695
# F1-Score: 0.597
# Recall: 0.5958
# Precision: 0.5981
# EQM: 0.4305
#
# Usando criterion=gini e max_features=sqrt:
# Score treino: 0.9998
# Accuracy: 0.5652
# F1-Score: 0.5947
# Recall: 0.5962
# Precision: 0.5933
# EQM: 0.4348
#
# Usando criterion=gini e max_features=log2:
# Score treino: 0.9998
# Accuracy: 0.5747
# F1-Score: 0.603
# Recall: 0.6035
# Precision: 0.6024
# EQM: 0.4253
#
# Usando criterion=entropy e max_features=auto:
# Score treino: 0.9998
# Accuracy: 0.5623
# F1-Score: 0.5945
# Recall: 0.5997
# Precision: 0.5894
# EQM: 0.4377
#
# Usando criterion=entropy e max_features=sqrt:
# C:\Users\Kanel\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\Kanel\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# Score treino: 0.9998
# Accuracy: 0.5727
# F1-Score: 0.6059
# Recall: 0.6139
# Precision: 0.5981
# EQM: 0.4273
#
# Usando criterion=entropy e max_features=log2:
# Score treino: 0.9998
# Accuracy: 0.5654
# F1-Score: 0.593
# Recall: 0.5917
# Precision: 0.5943
# EQM: 0.4346
#
# Usando criterion=log_loss e max_features=auto:
# Score treino: 0.9998
# Accuracy: 0.5667
# F1-Score: 0.5948
# Recall: 0.5944
# Precision: 0.5953
# EQM: 0.4333
#
# Usando criterion=log_loss e max_features=sqrt:
# Score treino: 0.9998
# Accuracy: 0.5697
# F1-Score: 0.6011
# Recall: 0.6059
# Precision: 0.5964
# EQM: 0.4303
#
# Usando criterion=log_loss e max_features=log2:
# Score treino: 0.9998
# Accuracy: 0.5734
# F1-Score: 0.6019
# Recall: 0.6028
# Precision: 0.6011
# EQM: 0.4266
# C:\Users\Kanel\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
