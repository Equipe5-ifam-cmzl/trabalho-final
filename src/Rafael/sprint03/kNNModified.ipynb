# %% [markdown]
# ## Modificando o algoritmo kNN

# %%
import pandas as pd

link = 'C:/Users/Kanel/vEnv/trabalho-final/database/Financial-Data.csv'

df = pd.read_csv(link)
df
# Out:
#        Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# 0                   3                     3                   6
# 1                   6                     3                   2
# 2                   0                     0                   7
# 3                   6                     1                   2
# 4                   5                     2                   2
# ...               ...                   ...                 ...
# 17903               5                     3                   2
# 17904               2                     1                   3
# 17905               5                     1                   1
# 17906               3                     5                   6
# 17907               4                    10                   4
#
#        personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                       2  ...               550       36200      0.737398
# 1                       7  ...               600       30150      0.738510
# 2                       1  ...               450       34550      0.642993
# 3                       7  ...               700       42150      0.665224
# 4                       8  ...              1100       53850      0.617361
# ...                   ...  ...               ...         ...           ...
# 17903                   6  ...               700       71700      0.691126
# 17904                   3  ...               800       51800      0.648525
# 17905                   8  ...              1200       59650      0.677975
# 17906                   1  ...               400       80200      0.642741
# 17907                   1  ...               600       64950      0.720889
#
#        risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0          0.903517      0.487712      0.515977           0.580918
# 1          0.881027      0.713423      0.826402           0.730720
# 2          0.766554      0.595018      0.762284           0.531712
# 3          0.960832      0.767828      0.778831           0.792552
# 4          0.857560      0.613487      0.665523           0.744634
# ...             ...           ...           ...                ...
# 17903      0.928196      0.664112      0.838012           0.727705
# 17904      0.970832      0.699241      0.844724           0.774918
# 17905      0.918141      0.687981      0.939101           0.472045
# 17906      0.885684      0.456448      0.686823           0.406568
# 17907      0.874372      0.505565      0.631619           0.846163
#
#        ext_quality_score_2  inquiries_last_month  e_signed
# 0                 0.380918                    10         1
# 1                 0.630720                     9         0
# 2                 0.531712                     7         0
# 3                 0.592552                     8         1
# 4                 0.744634                    12         0
# ...                    ...                   ...       ...
# 17903             0.627705                     2         0
# 17904             0.474918                     3         0
# 17905             0.672045                     9         0
# 17906             0.406568                     3         1
# 17907             0.846163                     4         1
#
# [17908 rows x 21 columns]

# %%
y = df['e_signed'] # coluna-alvo
x = df[[
    'risk_score', 'amount_requested', 'has_debt', 'income' 
]] # colunas com melhor correlação de Pearson

# x = df -> para usar todas as features

# %%
# dataset em 30% para testes
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size=0.3, random_state=2811)

print(f"Train Set: {x_train.shape}, \nTest Set: {x_test.shape}")
# Out:
# Train Set: (12535, 4),
# Test Set: (5373, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# resultados do R2 Score
from sklearn import metrics

print(f'Score treino: {model.score(x_train, y_train).round(4)}')
predicts = model.predict(x_test)
print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
# Out:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448

# %% [markdown]
# Realizando modificações

# %%
pesos = ['uniform','distance']
algoritmos = ['auto', 'ball_tree', 'kd_tree', 'brute']
met = ['cityblock','euclidean','l1','l2','manhattan']

# %%
for x in range(len(pesos)):
    for y in range(len(algoritmos)):
        for z in range(len(met)):
            print(f'Usando weights={pesos[x]}, algorithm={algoritmos[y]} e metric={met[z]}:')
            model = KNeighborsClassifier(weights=pesos[x], algorithm=algoritmos[y], metric=met[z])
            model.fit(x_train, y_train)
            print(f'Score treino: {model.score(x_train, y_train).round(4)}')
            predicts = model.predict(x_test)
            print(f'Accuracy: {metrics.accuracy_score(y_test, predicts).round(4)}')
            print(f'F1-Score: {metrics.f1_score(y_test, predicts).round(4)}')
            print(f'Recall: {metrics.recall_score(y_test, predicts).round(4)}')
            print(f'Precision: {metrics.precision_score(y_test, predicts).round(4)}')
            print(f'EQM: {metrics.mean_squared_error(y_test, predicts).round(4)}')
            print('')
# Out:
# Usando weights=uniform, algorithm=auto e metric=cityblock:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=auto e metric=euclidean:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=auto e metric=l1:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=auto e metric=l2:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=auto e metric=manhattan:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=ball_tree e metric=cityblock:
# Score treino: 0.7227
# Accuracy: 0.5509
# F1-Score: 0.5933
# Recall: 0.6122
# Precision: 0.5755
# EQM: 0.4491
#
# Usando weights=uniform, algorithm=ball_tree e metric=euclidean:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=ball_tree e metric=l1:
# Score treino: 0.7227
# Accuracy: 0.5509
# F1-Score: 0.5933
# Recall: 0.6122
# Precision: 0.5755
# EQM: 0.4491
#
# Usando weights=uniform, algorithm=ball_tree e metric=l2:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=ball_tree e metric=manhattan:
# Score treino: 0.7227
# Accuracy: 0.5509
# F1-Score: 0.5933
# Recall: 0.6122
# Precision: 0.5755
# EQM: 0.4491
#
# Usando weights=uniform, algorithm=kd_tree e metric=cityblock:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=kd_tree e metric=euclidean:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=kd_tree e metric=l1:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=kd_tree e metric=l2:
# Score treino: 0.7199
# Accuracy: 0.5552
# F1-Score: 0.5968
# Recall: 0.6153
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=kd_tree e metric=manhattan:
# Score treino: 0.7231
# Accuracy: 0.5507
# F1-Score: 0.5924
# Recall: 0.6101
# Precision: 0.5756
# EQM: 0.4493
#
# Usando weights=uniform, algorithm=brute e metric=cityblock:
# Score treino: 0.723
# Accuracy: 0.5502
# F1-Score: 0.5928
# Recall: 0.6118
# Precision: 0.5748
# EQM: 0.4498
#
# Usando weights=uniform, algorithm=brute e metric=euclidean:
# Score treino: 0.7201
# Accuracy: 0.5552
# F1-Score: 0.597
# Recall: 0.6157
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=brute e metric=l1:
# Score treino: 0.723
# Accuracy: 0.5502
# F1-Score: 0.5928
# Recall: 0.6118
# Precision: 0.5748
# EQM: 0.4498
#
# Usando weights=uniform, algorithm=brute e metric=l2:
# Score treino: 0.7201
# Accuracy: 0.5552
# F1-Score: 0.597
# Recall: 0.6157
# Precision: 0.5794
# EQM: 0.4448
#
# Usando weights=uniform, algorithm=brute e metric=manhattan:
# Score treino: 0.723
# Accuracy: 0.5502
# F1-Score: 0.5928
# Recall: 0.6118
# Precision: 0.5748
# EQM: 0.4498
#
# Usando weights=distance, algorithm=auto e metric=cityblock:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=auto e metric=euclidean:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=auto e metric=l1:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=auto e metric=l2:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=auto e metric=manhattan:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=ball_tree e metric=cityblock:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5979
# Recall: 0.6157
# Precision: 0.5811
# EQM: 0.4431
#
# Usando weights=distance, algorithm=ball_tree e metric=euclidean:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=ball_tree e metric=l1:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5979
# Recall: 0.6157
# Precision: 0.5811
# EQM: 0.4431
#
# Usando weights=distance, algorithm=ball_tree e metric=l2:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=ball_tree e metric=manhattan:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5979
# Recall: 0.6157
# Precision: 0.5811
# EQM: 0.4431
#
# Usando weights=distance, algorithm=kd_tree e metric=cityblock:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=kd_tree e metric=euclidean:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=kd_tree e metric=l1:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=kd_tree e metric=l2:
# Score treino: 0.9998
# Accuracy: 0.5593
# F1-Score: 0.5995
# Recall: 0.6163
# Precision: 0.5835
# EQM: 0.4407
#
# Usando weights=distance, algorithm=kd_tree e metric=manhattan:
# Score treino: 0.9998
# Accuracy: 0.5569
# F1-Score: 0.5973
# Recall: 0.6143
# Precision: 0.5813
# EQM: 0.4431
#
# Usando weights=distance, algorithm=brute e metric=cityblock:
# Score treino: 0.9998
# Accuracy: 0.5565
# F1-Score: 0.5979
# Recall: 0.6163
# Precision: 0.5806
# EQM: 0.4435
#
# Usando weights=distance, algorithm=brute e metric=euclidean:
# Score treino: 0.9998
# Accuracy: 0.5595
# F1-Score: 0.5998
# Recall: 0.617
# Precision: 0.5836
# EQM: 0.4405
#
# Usando weights=distance, algorithm=brute e metric=l1:
# Score treino: 0.9998
# Accuracy: 0.5565
# F1-Score: 0.5979
# Recall: 0.6163
# Precision: 0.5806
# EQM: 0.4435
#
# Usando weights=distance, algorithm=brute e metric=l2:
# Score treino: 0.9998
# Accuracy: 0.5595
# F1-Score: 0.5998
# Recall: 0.617
# Precision: 0.5836
# EQM: 0.4405
#
# Usando weights=distance, algorithm=brute e metric=manhattan:
# Score treino: 0.9998
# Accuracy: 0.5565
# F1-Score: 0.5979
# Recall: 0.6163
# Precision: 0.5806
# EQM: 0.4435
